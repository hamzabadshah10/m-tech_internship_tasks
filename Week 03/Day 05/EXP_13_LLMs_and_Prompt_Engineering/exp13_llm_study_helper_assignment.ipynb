# %% [markdown]
# # Experiment 13: Large Language Models (Study Helper)
# ### Home Assignment

# %%
def study_helper(topic):
    # Mock function replacing actual OpenAI call
    return f'Summary of {topic}: Important AI concept.\nQuiz: \n1. What is {topic}?\n2. How to implement {topic}?\n3. Why is {topic} useful?'
print(study_helper('Transformers'))
