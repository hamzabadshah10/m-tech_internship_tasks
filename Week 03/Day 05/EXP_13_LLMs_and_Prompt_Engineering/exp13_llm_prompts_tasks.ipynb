# %% [markdown]
# # Experiment 13: Large Language Models (Prompt Engineering)
# ### Lab Tasks, Viva, MCQs

# %% [markdown]
# ### Prompt Examples
# - **Zero-shot**: 'Solve 2x+4=10'
# - **Few-shot**: '1+1=2, 2+2=4. Solve 3+3=?'
# - **Chain-of-thought**: 'Let's solve 2x+4=10 step by step.'
#
# ### Viva Questions
# 1. **What does LLM predict?** The next token.
# 2. **What is a token?** A chunk of text.
# 3. **Context window?** Max text read at once.
# 4. **Temperature?** Randomness/Creativity.
# 5. **Prompt Engineering?** Writing clear instructions.
# 6. **Zero vs Few shot?** Zero has no examples, Few has examples.
#
# ### MCQs
# - Q1: (b) token
# - Q2: (b) creative/random
# - Q3: (b) few-shot
# - Q4: (b) context window
# - Q5: (b) chain-of-thought
