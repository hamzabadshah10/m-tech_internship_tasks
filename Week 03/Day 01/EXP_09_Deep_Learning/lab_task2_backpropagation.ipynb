# %% [markdown]
# # Task 2: Backpropagation Concept
#
# ## Objective
# Understand how weights are updated.
#
# ## Theory
# Backpropagation calculates the gradient of the loss function.

# %%
# Required Libraries & Import Statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Ensure outputs folder exists
os.makedirs('outputs', exist_ok=True)

# %% [markdown]
# ## Step-by-Step Code - Part 1

# %%
print('Backpropagation updates weights using Gradient Descent: W = W - lr * dLoss/dW')

# %% [markdown]
# ## Explanation of Results
# Results discussed above.
#
# ## Conclusion
# Task completed successfully.
