# %% [markdown]
# # Task 1: OpenCV Image Processing
#
# ## Objective
# Load, grayscale, and display an image using OpenCV.
#
# ## Theory
# OpenCV is used for computer vision tasks.

# %%
# Required Libraries & Import Statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Ensure outputs folder exists
os.makedirs('outputs', exist_ok=True)

# %% [markdown]
# ## Step-by-Step Code - Part 1

# %%
# import cv2
# img = cv2.imread('image.jpg', 0) # Read as grayscale
# cv2.imwrite('outputs/gray.jpg', img)
print('OpenCV operations simulated.')

# %% [markdown]
# ## Explanation of Results
# Results discussed above.
#
# ## Conclusion
# Task completed successfully.
