# %% [markdown]
# # Experiment 12: Generative AI (Concepts)
# ### In-Class Practice

# %% [markdown]
# ### Generative vs Discriminative
# - **Discriminative Model:** Separates or labels data (e.g. cat vs dog).
# - **Generative Model:** Learns distribution to create new realistic samples (GANs, VAEs).
