# %% [markdown]
# # Experiment 12: Generative AI (Diffusion Models)
# ### Lab Tasks, Viva, MCQs

# %%
# Pseudocode for using Diffusers locally
try:
    from diffusers import StableDiffusionPipeline
    import torch
    print('Hugging Face Diffusers loaded.')
except ImportError:
    print('`pip install diffusers torch` to run actual generations locally.')

# %% [markdown]
# ### Viva Questions
# 1. **Generative vs Discriminative?** Create data vs Label data.
# 2. **GAN interaction?** Generator makes fakes, Discriminator catches them.
# 3. **Diffusion core idea?** Remove noise step-by-step.
# 4. **Latent Space?** Compact encoded representation of data.
# 5. **Applications?** Image generation, text generation.
# 6. **Risks?** Deepfakes, misinformation.
#
# ### MCQs
# - Q1: (b) 2
# - Q2: (b) Generator
# - Q3: (c) Diffusion model
# - Q4: (b) create new data
# - Q5: (a) risk of generative AI
