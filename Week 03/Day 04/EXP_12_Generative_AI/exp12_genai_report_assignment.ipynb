# %% [markdown]
# # Experiment 12: Generative AI (Report)
# ### Home Assignment

# %% [markdown]
# ### GANs vs Diffusion Models
# **GANs:** Fast generation, highly competitive adversarial training which can be hard to stabilize.
# **Diffusion:** Reverses noise mapping. Highly detailed but computationally heavy for inference.
