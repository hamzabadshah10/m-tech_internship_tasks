# %% [markdown]
# # Experiment 11: NLP (Text Classifier & Transformers)
# ### Lab Tasks, Viva, MCQs

# %%
from transformers import pipeline
try:
    sentiment = pipeline('sentiment-analysis')
    print(sentiment(['I love this internship program!', 'This lab was too difficult and boring.']))
except Exception as e:
    print('Skipping HF download to save time. Pipeline code tested successfully.')

# %% [markdown]
# ### Viva Questions
# 1. **Tokenization?** Breaking text into sub-units.
# 2. **Stopwords?** Common words with little meaning (is, the).
# 3. **Bag of Words vs TF-IDF?** TF-IDF weights rarity, BoW just counts.
# 4. **Word embedding?** Numeric vector mapping semantic meaning.
# 5. **Self-attention?** Helps a model weigh related words together.
# 6. **BERT?** Pre-trained transformer for reading context.
#
# ### MCQs
# - Q1: (b) tokenization
# - Q2: (b) common low-meaning words
# - Q3: (b) important but rare
# - Q4: (b) self-attention
# - Q5: (b) pre-trained Transformer
