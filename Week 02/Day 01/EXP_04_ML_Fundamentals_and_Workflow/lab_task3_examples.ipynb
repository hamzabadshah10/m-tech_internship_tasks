# %% [markdown]
# # Task 3: Examples of ML
#
# ## Objective
# Give three real-world examples each of classification and regression problems.
#
# ## Theory
# Classification vs Regression.

# %%
# Required Libraries & Import Statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Ensure outputs folder exists
os.makedirs('outputs', exist_ok=True)

# %% [markdown]
# ## Step-by-Step Code - Part 1

# %%
print('Regression: House Price, Stock Price, Age\nClassification: Spam, Disease, Image Recognition')

# %% [markdown]
# ## Explanation of Results
# Results discussed above.
#
# ## Conclusion
# Task completed successfully.
