# %% [markdown]
# # Task 3: KNN Comparison
#
# ## Objective
# Compare KNN with k = 1, 3, 5, 7 on the Iris dataset in a small table.
#
# ## Theory
# K-Nearest Neighbors.

# %%
# Required Libraries & Import Statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Ensure outputs folder exists
os.makedirs('outputs', exist_ok=True)

# %% [markdown]
# ## Step-by-Step Code - Part 1

# %%
from sklearn.neighbors import KNeighborsClassifier
for k in [1, 3, 5, 7]:
    clf = KNeighborsClassifier(n_neighbors=k).fit(Xtr, ytr)
    print(f'k={k}, Acc={clf.score(Xte, yte)}')

# %% [markdown]
# ## Explanation of Results
# Results discussed above.
#
# ## Conclusion
# Task completed successfully.
