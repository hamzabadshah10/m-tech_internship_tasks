# %% [markdown]
# # Task 1: Regression with Metrics
#
# ## Objective
# Train a LinearRegression model on any real dataset and report R² and RMSE.
#
# ## Theory
# R2 and RMSE metrics.

# %%
# Required Libraries & Import Statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Ensure outputs folder exists
os.makedirs('outputs', exist_ok=True)

# %% [markdown]
# ## Step-by-Step Code - Part 1

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import numpy as np

X = np.linspace(0, 10, 100).reshape(-1, 1)
y = 2.2 * X.ravel() + 5 + np.random.randn(100)
Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=0.2)
model = LinearRegression().fit(Xtr, ytr)
p = model.predict(Xte)
print('R2:', r2_score(yte, p))
print('RMSE:', mean_squared_error(yte, p)**0.5)

# %% [markdown]
# ## Explanation of Results
# Results discussed above.
#
# ## Conclusion
# Task completed successfully.
