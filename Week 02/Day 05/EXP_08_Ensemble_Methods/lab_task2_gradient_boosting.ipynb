# %% [markdown]
# # Task 2: XGBoost and LightGBM
#
# ## Objective
# Train boosting models to compare performance.
#
# ## Theory
# Boosting sequentially builds trees to correct previous errors.

# %%
# Required Libraries & Import Statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Ensure outputs folder exists
os.makedirs('outputs', exist_ok=True)

# %% [markdown]
# ## Step-by-Step Code - Part 1

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=50).fit(X, y)
print(f'Accuracy: {gbc.score(X, y):.3f}')

# %% [markdown]
# ## Explanation of Results
# Results discussed above.
#
# ## Conclusion
# Task completed successfully.
